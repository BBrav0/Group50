# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

df = pd.read_csv("Covid19 Vaccinations.csv", sep=",")
df.head(10)
# Out:
#         month   neighborhood_municipality  total_partially_vaccinated  \
# 0  2020-12-01   East Liberty (Pittsburgh)                         174
# 1  2020-12-01     Greenfield (Pittsburgh)                         214
# 2  2020-12-01    Morningside (Pittsburgh)                         105
# 3  2020-12-01                    Richland                         212
# 4  2020-12-01  South Oakland (Pittsburgh)                          57
# 5  2020-12-01           Upper Saint Clair                         458
# 6  2021-01-01            Baldwin Township                         147
# 7  2021-01-01      Beechview (Pittsburgh)                         388
# 8  2021-01-01                  Bell Acres                          85
# 9  2021-01-01                    Bellevue                         480
#
#    total_fully_vaccinated  total_fully_vaccinated_w_booster
# 0                       1                                 0
# 1                       1                                 0
# 2                       1                                 0
# 3                       1                                 0
# 4                       1                                 0
# 5                       1                                 0
# 6                      64                                 0
# 7                     147                                 0
# 8                      51                                 0
# 9                     160                                 0

# %% [markdown]
# First lets get rid of the month tab, because we don't need it. We will just add together all the values for each city from each month.

# %%
df =  df.drop(labels="month", axis=1)
df.head(10)
# Out:
#     neighborhood_municipality  total_partially_vaccinated  \
# 0   East Liberty (Pittsburgh)                         174
# 1     Greenfield (Pittsburgh)                         214
# 2    Morningside (Pittsburgh)                         105
# 3                    Richland                         212
# 4  South Oakland (Pittsburgh)                          57
# 5           Upper Saint Clair                         458
# 6            Baldwin Township                         147
# 7      Beechview (Pittsburgh)                         388
# 8                  Bell Acres                          85
# 9                    Bellevue                         480
#
#    total_fully_vaccinated  total_fully_vaccinated_w_booster
# 0                       1                                 0
# 1                       1                                 0
# 2                       1                                 0
# 3                       1                                 0
# 4                       1                                 0
# 5                       1                                 0
# 6                      64                                 0
# 7                     147                                 0
# 8                      51                                 0
# 9                     160                                 0

# %% [markdown]
# Next, because this is a dataset of all of Allegheny we want to only get the neighborhoods with Pittsburgh listed in parentheses.

# %%
for index, row in df.iterrows():
    if 'Pittsburgh' not in  row['neighborhood_municipality']:
        df = df.drop(index)
df.head(10)
# Out:
#          neighborhood_municipality  total_partially_vaccinated  \
# 0        East Liberty (Pittsburgh)                         174
# 1          Greenfield (Pittsburgh)                         214
# 2         Morningside (Pittsburgh)                         105
# 4       South Oakland (Pittsburgh)                          57
# 7           Beechview (Pittsburgh)                         388
# 13  Central Northside (Pittsburgh)                         225
# 14    Central Oakland (Pittsburgh)                         313
# 16       East Liberty (Pittsburgh)                         428
# 17             Esplen (Pittsburgh)                           8
# 20           Garfield (Pittsburgh)                         175
#
#     total_fully_vaccinated  total_fully_vaccinated_w_booster
# 0                        1                                 0
# 1                        1                                 0
# 2                        1                                 0
# 4                        1                                 0
# 7                      147                                 0
# 13                      97                                 0
# 14                     110                                 0
# 16                     214                                 0
# 17                       2                                 0
# 20                      92                                 0

# %% [markdown]
# Now that we have only the data we want in our dataframe, lets sort it to give each neighborhood a value.
#
# The three values are partially vaccinated, fully vaccinated, and fully vaccinated with a booster.
#
# We can assign these values with 1, 1.5, and 2, the more vaccinations the safer!
#
# We can start by totalling this value with a multiplier, and adding them to a dictionary. We can also remove the
# ' (Pittsburgh)' in the name to make our data look cleaner.

# %%
df = df.apply(lambda x: x.replace({' \(Pittsburgh\)':''},regex=True))
values = {}
for index, row in df.iterrows():
    if row['neighborhood_municipality'] in values:
        part = row['total_partially_vaccinated']*1
        full = row['total_fully_vaccinated']*1.5
        boost = row['total_fully_vaccinated_w_booster']*2
        values[row['neighborhood_municipality']] = values[row['neighborhood_municipality']] + (part+full+boost)
    else:
        part = row['total_partially_vaccinated']*1
        full = row['total_fully_vaccinated']*1.5
        boost = row['total_fully_vaccinated_w_booster']*2
        values[row['neighborhood_municipality']] = (part+full+boost)
values
# Out:
# {'East Liberty': 14361.0,
#  'Greenfield': 20130.5,
#  'Morningside': 9216.5,
#  'South Oakland': 7051.5,
#  'Beechview': 17508.0,
#  'Central Northside': 7734.5,
#  'Central Oakland': 8383.0,
#  'Esplen': 435.0,
#  'Garfield': 7992.0,
#  'Hays': 707.5,
#  'Homewood North': 4092.5,
#  'Homewood West': 1150.0,
#  'Knoxville': 5760.5,
#  'Lincoln-Lemington-Belmar': 7327.5,
#  'Marshall-Shadeland': 7223.5,
#  'Mt. Oliver': 831.0,
#  'New Homestead': 2206.0,
#  'North Oakland': 16393.5,
#  'Point Breeze': 17654.0,
#  'Shadyside': 41176.0,
#  'Southside Slopes': 9303.5,
#  'St. Clair': 404.5,
#  'Banksville': 10766.5,
#  'Brighton Heights': 16574.0,
#  'Central Business District': 12703.5,
#  'Central Lawrenceville': 13391.5,
#  'Duquesne Heights': 6322.5,
#  'East Allegheny': 4576.0,
#  'Fairywood': 2347.0,
#  'Fineview': 2083.5,
#  'Northview Heights': 1600.0,
#  'Ridgemont': 1173.0,
#  'Squirrel Hill North': 27880.5,
#  'Squirrel Hill South': 46909.5,
#  'Stanton Heights': 12684.0,
#  'Strip District': 5342.0,
#  'West End': 448.0,
#  'Allegheny West': 1389.0,
#  'Arlington Heights': 280.5,
#  'Bluff': 3051.0,
#  'Bon Air': 1792.5,
#  'California-Kirkbride': 1221.0,
#  'Chartiers City': 975.5,
#  'Crafton Heights': 8347.0,
#  'East Carnegie': 1039.5,
#  'East Pittsburgh': 2694.0,
#  'Hazelwood': 7772.0,
#  'Highland Park': 19576.5,
#  'Homewood South': 3969.5,
#  'Larimer': 3021.5,
#  'Lincoln Place': 7233.0,
#  'Mount Washington': 19448.0,
#  'Oakwood': 2343.0,
#  'Overbrook': 7836.5,
#  'Perry South': 7472.0,
#  'Point Breeze North': 5330.0,
#  'Polish Hill': 2980.0,
#  'Sheraden': 9573.5,
#  'Southside Flats': 18198.5,
#  'Spring Garden': 1511.5,
#  'Swisshelm Park': 3853.5,
#  'Troy Hill': 6669.0,
#  'Undefined': 141.5,
#  'Upper Hill': 4191.0,
#  'West Oakland': 3125.0,
#  'Westwood': 8022.5,
#  'Windgap': 3228.0,
#  'Allentown': 4234.0,
#  'Bloomfield': 23722.5,
#  'Crawford-Roberts': 5751.5,
#  'Elliott': 4521.0,
#  'Friendship': 5264.0,
#  'Manchester': 4793.5,
#  'Regent Square': 3205.5,
#  'South Shore': 605.0,
#  'Upper Lawrenceville': 6713.5,
#  'Bedford Dwellings': 1899.0,
#  'Beltzhoover': 3162.0,
#  'Brookline': 32014.5,
#  'Carrick': 20905.5,
#  'Chateau': 107.5,
#  'Lower Lawrenceville': 7366.5,
#  'Middle Hill': 3450.5,
#  'Spring Hill-City View': 4904.5,
#  'Summer Hill': 2450.0,
#  'Terrace Village': 3703.0,
#  'Allegheny Center': 3346.5,
#  'Arlington': 3210.5,
#  'East Hills': 4401.0,
#  'Glen Hazel': 1645.0,
#  'North Shore': 835.5,
#  'Perry North': 8618.5}

# %% [markdown]
# We now have all of our Pittsburgh neighborhoods and their point values in terms of vaccinations. Let's convert it into a dataframe and sort it by the highest points.

# %%
newList = list(values.items())
new = pd.DataFrame (newList, columns = ['City','Vax Points']) 
new = new.sort_values(by=['Vax Points'], ascending=False)
new
# Out:
#                    City  Vax Points
# 33  Squirrel Hill South     46909.5
# 19            Shadyside     41176.0
# 78            Brookline     32014.5
# 32  Squirrel Hill North     27880.5
# 68           Bloomfield     23722.5
# ..                  ...         ...
# 7                Esplen       435.0
# 21            St. Clair       404.5
# 38    Arlington Heights       280.5
# 62            Undefined       141.5
# 80              Chateau       107.5
#
# [92 rows x 2 columns]

# %% [markdown]
# Let's now make a graph of our data.

# %%
new.plot(x='City', y='Vax Points', kind='bar')

# %% [markdown]
# To make our data clearer and see the most protected cities, we can plot just the cities with the highest points.

# %%
new.head(10).plot(x='City', y='Vax Points', kind='bar')

# %% [markdown]
# In conclusion, the most protected neighborhoods from Covid19 in Pittsburgh are the ten we see listed above, with a big emphasis on Squirel Hill South and Shadyside being outliers on the higher side.
